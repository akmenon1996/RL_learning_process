# %%
import time
import psutil
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
plt.rcParams['animation.html']='jshtml'

# %%
def lab_sim(TC):
    dTCdt = ((23-TC)+0.8*50)/120
    return dTCdt

# %%
new_temp_arr=[]
i = 0 
x,y = [],[]
y1=[]
def run_sim(TC,optimum_temp,i,arr):
    arr.append(TC)
    x.append(i)
    y.append(TC)
    y1.append(optimum_temp)    
    ax.plot(x,y,color='b')
    ax.plot(x,y1,color='r')
    fig.canvas.draw()
    ax.set_xlim(i-50,i+50)
    #i+=1
    if i>=200:
        return arr
    elif TC<optimum_temp:
        dtCdt = lab_sim(TC)
        TC+=dtCdt
        i+=1
        return run_sim(TC,optimum_temp,i,arr)
    elif TC>=optimum_temp:
        i+=1
        return run_sim(TC,optimum_temp,i,arr)
    else:
        return arr

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Tsim_23 = run_sim(23,40,0,[])
#Tsim_28 = run_sim(25,28,[])
#Tsim_42 = run_sim(27,62.5,[])

# %%
plt.close()
